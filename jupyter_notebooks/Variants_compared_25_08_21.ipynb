# %% [markdown]
# ### Compare variant calls and annotations from two RNA-seq experiments

# %%
import sys
import pandas as pd
import os

input_file1 = "/cluster/db/mecoulter/CEMartinez_RNAseq-209915706/results/bcftools/3H_locus_filtered.anno.vcf"
input_file2 = "/cluster/db/mecoulter/RNAseq2/bcftools/3H_locus_filtered.anno.vcf"

first_set = set()
second_set = set()

for line in open(input_file1):#Barke - Int19/Int56
    if line.startswith("#"):
        continue
    fields = line.rstrip().split("\t")
    SNP_position = fields[1]
    ref = fields[3]
    alt = fields[4]
    variant_id = f"{SNP_position}_{ref}_{alt}"
    first_set.add(variant_id)

print(f"{len(first_set)} unique variants in experiment one")
    
for line in open(input_file2):#Barke/Int_124_17 - Int_124_52
    if line.startswith("#"):
        continue
    fields = line.rstrip().split("\t")
    SNP_position = fields[1]
    ref = fields[3]
    alt = fields[4]
    variant_id = f"{SNP_position}_{ref}_{alt}"
    second_set.add(variant_id)

print(f"{len(second_set)} unique variants in experiment two")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-7cd38c0f031e> in <module>
#       9 second_set = set()
#      10
# ---> 11 for line in open(input_file1):#Barke - Int19/Int56
#      12     if line.startswith("#"):
#      13         continue
#
# FileNotFoundError: [Errno 2] No such file or directory: '/cluster/db/mecoulter/CEMartinez_RNAseq-209915706/results/bcftools/3H_locus_filtered.anno.vcf'

# %% [markdown]
# * What variants are shared between two experiments?

# %%
print(f"Number of shared variants: {len(first_set & second_set)}, proportion (compared to first set): {len(first_set & second_set)/len(first_set)} ")
# Out:
# Number of shared variants: 407, proportion (compared to first set): 0.2600638977635783

# %%
input_file = input_file1 

annotation_input = "/cluster/db/mecoulter/BaRT2v18/BaRT_2_18_annotation_genes.txt"

expression_info = "/cluster/db/mecoulter/RNAseq2/RNAquant_analysis_result/expressed_genes_both_adj_p_values.csv"


gene_annotation = pd.read_csv(expression_info,engine="c",index_col=0)

expressed_genes = set(gene_annotation.index)

print(f"Number of expressed genes in RNAseq dataset: {len(expressed_genes)}\n")#Sanity check



impact = {"MODIFIER":0, "LOW": 0, "MODERATE": 0, "HIGH": 0 }

gene_impact = {} #Per gene impact annotation
gene_SNP_annotation = {} #Per gene SNP annotation, HIGH or MODERATE only

annotation_counts = {}

for line in open(input_file):
	if line.startswith("#"):
		continue
	fields = line.rstrip().split("\t")
	INFO = fields[7]
	SNP_position = fields[1]
	annotations = INFO.split("ANN=")[1].split("=")[0].split(",")#List of all possible annotations
	for annotation in annotations:
		try:
			allele, p_annotation, putative_impact, position, gene, feature_type, transcript, transcript_type  = annotation.split("|")[:8]
		except ValueError:
			print(f"Error at position {SNP_position}! Annotation is {annotation}")
			sys.exit()
		gene_impact.setdefault(gene,set()).add(putative_impact)
		if putative_impact == "HIGH" or putative_impact == "MODERATE":
			gene_SNP_annotation.setdefault(gene,set()).add(p_annotation)

for gene, impacts in gene_impact.items():
	for putative_impact in impacts:
		impact[putative_impact] += 1

for gene, annotations in gene_SNP_annotation.items():
	for annotation in annotations:
		try:
			annotation_counts[annotation] += 1
		except KeyError:
			annotation_counts[annotation] = 1

print(f"Number of genes with each impact category: {impact}\n")#One gene can have multiple categories

print(f"Number of genes with either HIGH or MODERATE variants: {len(gene_SNP_annotation.keys())}\n")

print(f"Number of genes with HIGH or MODERATE variants with each annotation category: {annotation_counts}\n")

for gene, annotations in gene_SNP_annotation.items():
	annotation_list = ",".join(list(annotations))
	print(f"Gene {gene} annotations: {annotation_list}")

disruptive = {"stop_gained", "frameshift_variant", "start_lost"}

if annotation_input:
	gene_annotation = pd.read_csv(annotation_input, delimiter="\t",engine="c",index_col=0)


gene_annotation.head()

first_experiment_genes = set()

print("\nGenes with most impacting variants:\n")
for gene, annotations in gene_SNP_annotation.items():
    if len(annotations & disruptive) >= 1:
        annotation_list = ", ".join(list(annotations))
        pannzer = gene_annotation.at[gene,"Pannzer annotation"]
        try:
            pannzer1 = pannzer.split(";")[0]#Just use first in list otherwise too many
        except:#If pannzer object is nan
            pannzer1 = pannzer
        print(f"Gene {gene} ({pannzer1}, expressed?: {gene in expressed_genes}): {annotation_list} \n")
        first_experiment_genes.add(gene)
# Out:
# Number of expressed genes in RNAseq dataset: 19802
#
# Number of genes with each impact category: {'MODIFIER': 145, 'LOW': 72, 'MODERATE': 72, 'HIGH': 17}
#
# Number of genes with either HIGH or MODERATE variants: 74
#
# Number of genes with HIGH or MODERATE variants with each annotation category: {'missense_variant': 72, 'frameshift_variant': 9, 'splice_donor_variant&intron_variant': 2, 'disruptive_inframe_deletion': 4, 'stop_gained': 1, 'missense_variant&splice_region_variant': 3, 'splice_acceptor_variant&intron_variant': 4, 'disruptive_inframe_insertion': 1, 'conservative_inframe_insertion': 1, 'start_lost': 1, 'frameshift_variant&stop_gained': 1}
#
# Gene BaRT2v18chr3HG122620 annotations: missense_variant
# Gene BaRT2v18chr3HG122640 annotations: missense_variant,frameshift_variant
# Gene BaRT2v18chr3HG122660 annotations: missense_variant
# Gene BaRT2v18chr3HG122690 annotations: missense_variant
# Gene BaRT2v18chr3HG122720 annotations: missense_variant
# Gene BaRT2v18chr3HG122730 annotations: missense_variant
# Gene BaRT2v18chr3HG122740 annotations: missense_variant
# Gene BaRT2v18chr3HG122750 annotations: missense_variant
# Gene BaRT2v18chr3HG122760 annotations: missense_variant
# Gene BaRT2v18chr3HG122770 annotations: missense_variant,splice_donor_variant&intron_variant
# Gene BaRT2v18chr3HG122780 annotations: missense_variant
# Gene BaRT2v18chr3HG122790 annotations: missense_variant
# Gene BaRT2v18chr3HG122800 annotations: missense_variant,disruptive_inframe_deletion
# Gene BaRT2v18chr3HG122810 annotations: missense_variant,stop_gained,missense_variant&splice_region_variant
# Gene BaRT2v18chr3HG122810-BaRT2v18chr3HG122820 annotations: missense_variant,missense_variant&splice_region_variant
# Gene BaRT2v18chr3HG122820 annotations: missense_variant,disruptive_inframe_deletion
# Gene BaRT2v18chr3HG122830 annotations: missense_variant
# Gene BaRT2v18chr3HG122860 annotations: missense_variant
# Gene BaRT2v18chr3HG122870 annotations: missense_variant,frameshift_variant
# Gene BaRT2v18chr3HG122880 annotations: missense_variant
# Gene BaRT2v18chr3HG122890 annotations: missense_variant,frameshift_variant
# Gene BaRT2v18chr3HG122910 annotations: missense_variant
# Gene BaRT2v18chr3HG122920 annotations: missense_variant,missense_variant&splice_region_variant,splice_acceptor_variant&intron_variant
# Gene BaRT2v18chr3HG122930 annotations: missense_variant
# Gene BaRT2v18chr3HG122970 annotations: missense_variant
# Gene BaRT2v18chr3HG122990 annotations: missense_variant
# Gene BaRT2v18chr3HG123000 annotations: missense_variant
# Gene BaRT2v18chr3HG123010 annotations: missense_variant
# Gene BaRT2v18chr3HG123020 annotations: missense_variant
# Gene BaRT2v18chr3HG123030 annotations: missense_variant
# Gene BaRT2v18chr3HG123050 annotations: missense_variant
# Gene BaRT2v18chr3HG123040 annotations: missense_variant
# Gene BaRT2v18chr3HG123060 annotations: missense_variant
# Gene BaRT2v18chr3HG123070 annotations: missense_variant
# Gene BaRT2v18chr3HG123080 annotations: missense_variant
# Gene BaRT2v18chr3HG123090 annotations: missense_variant,splice_acceptor_variant&intron_variant
# Gene BaRT2v18chr3HG123100 annotations: splice_acceptor_variant&intron_variant
# Gene BaRT2v18chr3HG123110 annotations: missense_variant,frameshift_variant
# Gene BaRT2v18chr3HG123120 annotations: missense_variant
# Gene BaRT2v18chr3HG123140 annotations: missense_variant
# Gene BaRT2v18chr3HG123150 annotations: missense_variant
# Gene BaRT2v18chr3HG123160 annotations: missense_variant
# Gene BaRT2v18chr3HG123170 annotations: missense_variant
# Gene BaRT2v18chr3HG123220 annotations: missense_variant
# Gene BaRT2v18chr3HG123240 annotations: missense_variant
# Gene BaRT2v18chr3HG123230 annotations: missense_variant
# Gene BaRT2v18chr3HG123250 annotations: missense_variant
# Gene BaRT2v18chr3HG123260 annotations: missense_variant
# Gene BaRT2v18chr3HG123270 annotations: missense_variant
# Gene BaRT2v18chr3HG123280 annotations: missense_variant,disruptive_inframe_insertion
# Gene BaRT2v18chr3HG123350 annotations: missense_variant
# Gene BaRT2v18chr3HG123400 annotations: missense_variant,frameshift_variant
# Gene BaRT2v18chr3HG123410 annotations: missense_variant
# Gene BaRT2v18chr3HG123480 annotations: missense_variant,disruptive_inframe_deletion,frameshift_variant
# Gene BaRT2v18chr3HG123540 annotations: missense_variant,splice_donor_variant&intron_variant
# Gene BaRT2v18chr3HG123550 annotations: missense_variant
# Gene BaRT2v18chr3HG123600 annotations: missense_variant
# Gene BaRT2v18chr3HG123610 annotations: missense_variant
# Gene BaRT2v18chr3HG123630 annotations: missense_variant
# Gene BaRT2v18chr3HG123650 annotations: missense_variant,conservative_inframe_insertion
# Gene BaRT2v18chr3HG123660 annotations: missense_variant
# Gene BaRT2v18chr3HG123700 annotations: splice_acceptor_variant&intron_variant
# Gene BaRT2v18chr3HG123710 annotations: missense_variant
# Gene BaRT2v18chr3HG123730-BaRT2v18chr3HG123740 annotations: missense_variant
# Gene BaRT2v18chr3HG123730 annotations: missense_variant
# Gene BaRT2v18chr3HG123740 annotations: missense_variant,start_lost
# Gene BaRT2v18chr3HG123750 annotations: missense_variant
# Gene BaRT2v18chr3HG123760 annotations: missense_variant,frameshift_variant
# Gene BaRT2v18chr3HG123770 annotations: missense_variant,frameshift_variant
# Gene BaRT2v18chr3HG123780 annotations: missense_variant
# Gene BaRT2v18chr3HG123790 annotations: missense_variant
# Gene BaRT2v18chr3HG123800 annotations: missense_variant
# Gene BaRT2v18chr3HG123810 annotations: missense_variant
# Gene BaRT2v18chr3HG123830 annotations: missense_variant,disruptive_inframe_deletion,frameshift_variant&stop_gained,frameshift_variant
#
# Genes with most impacting variants:
#
# Gene BaRT2v18chr3HG122640 (Rab-GAP TBC domain-containing protein, expressed?: True): missense_variant, frameshift_variant
#
# Gene BaRT2v18chr3HG122810 (Glycosyltransferase, ALG3, expressed?: True): missense_variant, stop_gained, missense_variant&splice_region_variant
#
# Gene BaRT2v18chr3HG122870 (Ankyrin-1, expressed?: False): missense_variant, frameshift_variant
#
# Gene BaRT2v18chr3HG122890 (nan, expressed?: False): missense_variant, frameshift_variant
#
# Gene BaRT2v18chr3HG123110 (nan, expressed?: True): missense_variant, frameshift_variant
#
# Gene BaRT2v18chr3HG123400 (nan, expressed?: False): missense_variant, frameshift_variant
#
# Gene BaRT2v18chr3HG123480 (Folate-sensitive fragile site protein Fra10Ac1, expressed?: True): missense_variant, disruptive_inframe_deletion, frameshift_variant
#
# Gene BaRT2v18chr3HG123740 (TNase-like domain-containing protein, expressed?: False): missense_variant, start_lost
#
# Gene BaRT2v18chr3HG123760 (TNase-like domain-containing protein, expressed?: True): missense_variant, frameshift_variant
#
# Gene BaRT2v18chr3HG123770 (Cellulose synthase-like protein H1-like, expressed?: True): missense_variant, frameshift_variant
#
# Gene BaRT2v18chr3HG123830 (nan, expressed?: False): missense_variant, disruptive_inframe_deletion, frameshift_variant&stop_gained, frameshift_variant

# %%
input_file = input_file2

annotation_input = "/cluster/db/mecoulter/BaRT2v18/BaRT_2_18_annotation_genes.txt"

expression_info = "/cluster/db/mecoulter/RNAseq2/RNAquant_analysis_result/expressed_genes_both_adj_p_values.csv"


class SnpEffAnnotation:
    def __init__(self, annotation):
        try:
            self.allele, self.p_annotation, self.putative_impact, self.position, self.gene, self.feature_type, self.transcript, self.transcript_type  = annotation.split("|")[:8]
        except ValueError:
            print(f"Error at position {SNP_position}! Annotation is {annotation}")
            sys.exit()
    def __repr__(self):
        return self.p_annotation

class SnpEff:
    gene_impact = {}
    gene_SNP_annotation = {}
    Instances = {}#Gene: {position1: [annotations], position2: [annotations]}
    Instances_clean = {}
    position_info = {}
    
    def __init__(self, line):
        self.fields = line.rstrip().split("\t")
        self.INFO = self.fields[7]
        self.SNP_position = self.fields[1]
        self.reference_allele = self.fields[3]
        self.alternative_allele = self.fields[4]
        annotations = self.INFO.split("ANN=")[1].split("=")[0].split(",")#List of all possible annotations
        self.annotations = []
        for a in annotations:
            annotation = SnpEffAnnotation(a)
            self.annotations.append(annotation)
            self.gene_impact.setdefault(annotation.gene,[]).append(putative_impact)  
            
            if annotation.putative_impact == "HIGH" or annotation.putative_impact == "MODERATE":
                gene_SNP_annotation.setdefault(annotation.gene,[]).append(f"{annotation.p_annotation} : {self.SNP_position}")
                
            try:
                position_annotations = self.Instances[annotation.gene]
                position_annotations.setdefault(self.SNP_position, []).append(annotation)
                self.Instances[annotation.gene] = position_annotations
            except KeyError:
                positions_annotations = {}
                positions_annotations[self.SNP_position] = [annotation]
                self.Instances[annotation.gene] = positions_annotations
                
        self.position_info[self.SNP_position] = self
                
    def __getitem__(self, item):
        if self.Instances_clean:
            return self.Instances_clean[item]
        else:
            return self.Instances[item]
    
    def clean_up_annotations(self):
        """Many positions have multiple annotations.
        This is because of multiple transcripts. Most transcripts will be similar, 
        so will effectively have the same annotation. So remove duplicates. Will
        also remove annotations not of interest e.g upstream/ downstream"""
        
        not_interesting = {"downstream_gene_variant", "upstream_gene_variant", \
        "intergenic_region", "intron_variant"}
        
        for gene, position_annotation in self.Instances.items():
            position_annotation_clean = {}
            for position, annotations in position_annotation.items():
                annotations_cleaned = []
                all_p_annotations = set()
                for annotation in annotations:
                    if annotation.p_annotation not in all_p_annotations and annotation.p_annotation not in not_interesting:
                        #if annotation.putative_impact == "HIGH" or annotation.putative_impact == "MODERATE":
                        annotations_cleaned.append(annotation)
                        all_p_annotations.add(annotation.p_annotation)
                if annotations_cleaned:#Only keep high/moderate impact snps
                    position_annotation_clean[position] = annotations_cleaned
            self.Instances_clean[gene] = position_annotation_clean
    def __repr__(self):
        string = ""
        print_dict = self.Instances_clean if self.Instances_clean else self.Instances
        
        for gene, position_annotation in print_dict.items():
            string += f"{gene}: \n"
            for position, annotations in position_annotation.items():
                string += f"{position} : {','.join([str(annotation) for annotation in annotations])}\n"
            string += "\n"  
        return string
    
    def __len__(self):
        return(len(self.Instances.keys()))
    
    def write_tsv(self, outfile, gene_annotation):
        """Write a .csv file with results of cleaned up annotation. 
        Gene: Position: Annotation"""
        with open(outfile, "w") as out:
            out.write("Gene\tPosition\tAnnotation\tref allele\talt allele\tPanzzer Annotation\n")
            for gene, position_annotation in self.Instances_clean.items():
                index = 0
                try:
                    panz_annotation = gene_annotation.at[gene,"Pannzer annotation"]
                except KeyError:
                    print(f"KeyError for gene {gene}")
                    panz_annotation = "Not found"
                for position, annotations in position_annotation.items():
                    ref = self.position_info[position].reference_allele
                    alt = self.position_info[position].alternative_allele
                    out.write(f"{gene}\t{position}\t{','.join([str(annotation) for annotation in annotations])}\t\
                    {ref}\t{alt}\t")#
                    if not index:#Only write annotation once
                        out.write(f"{panz_annotation}\n")
                        index += 1
                    else:
                        out.write("\n")
        
        
        
            


gene_annotation = pd.read_csv(annotation_input,engine="c",index_col=0, sep="\t")

#expressed_genes = set(gene_annotation.index)



impact = {"MODIFIER":0, "LOW": 0, "MODERATE": 0, "HIGH": 0 }
locus = [33181340, 36970860]#3H locus boundaries on 3H

for line in open(input_file):
    #print(line)
    if line.startswith("#"):
        continue
    #print(line)
    position = int(line.rstrip().split("\t")[1])
    if position < locus[0] or position > locus[1]:#ONly include snps in 3H locus
        continue
    snpeff = SnpEff(line)

snpeff.clean_up_annotations()
print(snpeff)
print(f"Length of Instances is {len(snpeff)}")
snpeff.write_tsv("/cluster/db/mecoulter/RNAseq2/3H_locus_snpeff_gene_annotation.tab", gene_annotation)
# Out:
# BaRT2v18chr3HG122920:
# 33237835 : 5_prime_UTR_variant
# 33237849 : 5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
# 33241825 : missense_variant,missense_variant&splice_region_variant,3_prime_UTR_variant
# 33244171 : 3_prime_UTR_variant
# 33244188 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG122930:
# 33249270 : 5_prime_UTR_variant
# 33249283 : 5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
# 33250161 : synonymous_variant
# 33250186 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG122940:
#
# BaRT2v18chr3HG122940-BaRT2v18chr3HG122950:
#
# BaRT2v18chr3HG122960:
#
# BaRT2v18chr3HG122950-BaRT2v18chr3HG122960:
#
# BaRT2v18chr3HG122970:
# 33294871 : 3_prime_UTR_variant
# 33294891 : 3_prime_UTR_variant
# 33294929 : 3_prime_UTR_variant
# 33295153 : 3_prime_UTR_variant
# 33295177 : 3_prime_UTR_variant
# 33295236 : 3_prime_UTR_variant
# 33296098 : 3_prime_UTR_variant
# 33296420 : 3_prime_UTR_variant
# 33296572 : 3_prime_UTR_variant
# 33297796 : 3_prime_UTR_variant
# 33297999 : 3_prime_UTR_variant
# 33298005 : 3_prime_UTR_variant
# 33298006 : 3_prime_UTR_variant
# 33298503 : missense_variant
# 33298672 : missense_variant
# 33298677 : missense_variant
# 33298718 : synonymous_variant
# 33298968 : missense_variant
# 33299021 : synonymous_variant
#
# BaRT2v18chr3HG122980:
# 33300272 : 3_prime_UTR_variant
# 33300332 : 3_prime_UTR_variant
# 33300334 : 3_prime_UTR_variant
# 33300374 : 3_prime_UTR_variant
# 33300655 : synonymous_variant
# 33300944 : synonymous_variant
# 33301668 : 5_prime_UTR_variant
#
# BaRT2v18chr3HG122990:
# 33302658 : 3_prime_UTR_variant
# 33302831 : synonymous_variant
# 33305702 : missense_variant
# 33305765 : missense_variant
# 33305766 : synonymous_variant
# 33305985 : missense_variant
# 33305990 : synonymous_variant
# 33306244 : synonymous_variant
# 33306245 : missense_variant
# 33306298 : 5_prime_UTR_variant
#
# BaRT2v18chr3HG122980-BaRT2v18chr3HG122990:
#
# BaRT2v18chr3HG122990-BaRT2v18chr3HG123000:
#
# BaRT2v18chr3HG123000:
# 33574220 : 5_prime_UTR_variant
# 33574254 : 5_prime_UTR_variant
# 33574321 : synonymous_variant
# 33576083 : 3_prime_UTR_variant
# 33576106 : 3_prime_UTR_variant
# 33577017 : missense_variant,3_prime_UTR_variant
# 33577727 : synonymous_variant,3_prime_UTR_variant
# 33577868 : synonymous_variant,3_prime_UTR_variant
# 33578683 : missense_variant,3_prime_UTR_variant
# 33580916 : splice_region_variant,3_prime_UTR_variant
#
# BaRT2v18chr3HG123010:
# 33583952 : 3_prime_UTR_variant
# 33584530 : 3_prime_UTR_variant
# 33584650 : 3_prime_UTR_variant
# 33585221 : 3_prime_UTR_variant
# 33585276 : 3_prime_UTR_variant
# 33585379 : 3_prime_UTR_variant
# 33585425 : 3_prime_UTR_variant
# 33585446 : 3_prime_UTR_variant
# 33585484 : 3_prime_UTR_variant
# 33585917 : 3_prime_UTR_variant
# 33586222 : 3_prime_UTR_variant
# 33586252 : 3_prime_UTR_variant
# 33587087 : missense_variant
# 33587360 : 5_prime_UTR_variant
# 33587459 : 5_prime_UTR_variant
# 33588106 : 5_prime_UTR_variant
# 33588226 : 5_prime_UTR_variant
# 33589063 : 5_prime_UTR_variant
# 33589215 : 5_prime_UTR_variant
# 33589321 : 5_prime_UTR_variant
# 33589322 : 5_prime_UTR_variant
# 33589388 : 5_prime_UTR_variant
#
# BaRT2v18chr3HG123020:
# 33585379 : 5_prime_UTR_variant
# 33585425 : 5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
# 33585446 : 5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
# 33585484 : 5_prime_UTR_variant
# 33585917 : missense_variant
# 33586222 : synonymous_variant
# 33586252 : synonymous_variant
# 33587087 : missense_variant
# 33587360 : missense_variant,5_prime_UTR_variant
# 33587459 : missense_variant
# 33588106 : synonymous_variant
# 33588226 : synonymous_variant
# 33589063 : 3_prime_UTR_variant
# 33589215 : 3_prime_UTR_variant
# 33589321 : 3_prime_UTR_variant
# 33589322 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG123000-BaRT2v18chr3HG123010:
#
# BaRT2v18chr3HG123010-BaRT2v18chr3HG123030:
#
# BaRT2v18chr3HG123030:
# 33648878 : 3_prime_UTR_variant
# 33648926 : 3_prime_UTR_variant
# 33649037 : 3_prime_UTR_variant
# 33649080 : synonymous_variant,3_prime_UTR_variant
# 33649146 : synonymous_variant,3_prime_UTR_variant
# 33649575 : synonymous_variant,3_prime_UTR_variant
# 33650866 : splice_region_variant&intron_variant
# 33651066 : 3_prime_UTR_variant
# 33652198 : synonymous_variant
# 33652370 : 5_prime_UTR_variant
# 33652580 : 5_prime_UTR_variant
# 33652830 : 5_prime_UTR_variant
#
# BaRT2v18chr3HG123040:
# 33873335 : 5_prime_UTR_variant
# 33873337 : 5_prime_UTR_variant
# 33873343 : 5_prime_UTR_variant
# 33873492 : missense_variant
# 33873694 : synonymous_variant
# 33873715 : missense_variant
# 33873802 : missense_variant
# 33873988 : synonymous_variant
# 33875039 : 3_prime_UTR_variant
# 33876153 : missense_variant,3_prime_UTR_variant
# 33876216 : 3_prime_UTR_variant
# 33876241 : 3_prime_UTR_variant
# 33876282 : 3_prime_UTR_variant
# 33876372 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG123050:
# 33873335 : synonymous_variant
# 33873337 : missense_variant
# 33873343 : missense_variant
# 33873492 : missense_variant
# 33873694 : missense_variant
# 33873715 : missense_variant
# 33873802 : missense_variant
# 33873988 : missense_variant
# 33875039 : 5_prime_UTR_variant
# 33876153 : 5_prime_UTR_variant
# 33876216 : 5_prime_UTR_variant
# 33876241 : 5_prime_UTR_variant
# 33876282 : 5_prime_UTR_variant
#
# BaRT2v18chr3HG123030-BaRT2v18chr3HG123040:
#
# BaRT2v18chr3HG123040-BaRT2v18chr3HG123060:
#
# BaRT2v18chr3HG123060:
# 33916152 : missense_variant
# 33916709 : 3_prime_UTR_variant
# 33916754 : 3_prime_UTR_variant
# 33917015 : 3_prime_UTR_variant
# 33918364 : missense_variant,3_prime_UTR_variant
# 33918809 : synonymous_variant,3_prime_UTR_variant
# 33918899 : missense_variant,3_prime_UTR_variant
# 33919449 : 3_prime_UTR_variant
# 33919700 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG123070:
#
# BaRT2v18chr3HG123080:
# 34347332 : splice_region_variant&intron_variant,5_prime_UTR_variant
# 34347403 : 5_prime_UTR_variant
# 34347404 : 5_prime_UTR_variant
# 34347457 : 5_prime_UTR_variant
# 34347624 : synonymous_variant
# 34347967 : missense_variant
# 34348002 : synonymous_variant
# 34356216 : splice_region_variant&intron_variant
# 34356256 : missense_variant
# 34356257 : missense_variant
# 34356694 : missense_variant
# 34356712 : missense_variant
# 34356830 : synonymous_variant
# 34357135 : missense_variant,3_prime_UTR_variant
# 34357465 : 3_prime_UTR_variant
# 34357527 : 3_prime_UTR_variant
# 34357544 : 3_prime_UTR_variant
# 34357622 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG123090:
# 34538301 : missense_variant,5_prime_UTR_variant,3_prime_UTR_variant
# 34538680 : 5_prime_UTR_variant,3_prime_UTR_variant
# 34538707 : 5_prime_UTR_variant,3_prime_UTR_variant
# 34538771 : 5_prime_UTR_variant,3_prime_UTR_variant
# 34542090 : synonymous_variant,3_prime_UTR_variant
# 34542313 : synonymous_variant,3_prime_UTR_variant
# 34560902 : synonymous_variant,3_prime_UTR_variant
# 34562922 : synonymous_variant,3_prime_UTR_variant
# 34562964 : synonymous_variant,3_prime_UTR_variant
# 34564241 : missense_variant,3_prime_UTR_variant
# 34564453 : synonymous_variant,3_prime_UTR_variant
#
# BaRT2v18chr3HG123100:
# 34646132 : 5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
# 34646150 : 5_prime_UTR_variant
# 34646226 : 5_prime_UTR_variant
# 34646299 : 5_prime_UTR_variant
# 34647607 : synonymous_variant
# 34647682 : synonymous_variant
#
# BaRT2v18chr3HG123110:
# 34748456 : 5_prime_UTR_variant
# 34748574 : 5_prime_UTR_variant
# 34748648 : 5_prime_UTR_variant
# 34749036 : 5_prime_UTR_variant
# 34749044 : 5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
# 34749487 : 5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
# 34749525 : 5_prime_UTR_variant
# 34749617 : 5_prime_UTR_variant
# 34749683 : 5_prime_UTR_variant
# 34749723 : 5_prime_UTR_variant
# 34749786 : 5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
# 34750071 : 5_prime_UTR_variant
# 34750157 : 5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
# 34750203 : 5_prime_UTR_variant
# 34750217 : 5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
# 34750342 : 5_prime_UTR_variant
# 34750354 : 5_prime_UTR_variant
# 34750477 : synonymous_variant
# 34750705 : 3_prime_UTR_variant
# 34750986 : 3_prime_UTR_variant
# 34751060 : missense_variant,3_prime_UTR_variant
# 34751106 : missense_variant,3_prime_UTR_variant
# 34751148 : missense_variant,splice_region_variant&intron_variant,3_prime_UTR_variant
# 34751252 : frameshift_variant,3_prime_UTR_variant
# 34751342 : missense_variant,3_prime_UTR_variant
# 34751416 : missense_variant,3_prime_UTR_variant
# 34751473 : stop_lost,3_prime_UTR_variant
# 34751502 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG123110-BaRT2v18chr3HG123120:
#
# BaRT2v18chr3HG123120:
# 35079862 : 5_prime_UTR_variant
# 35079920 : 5_prime_UTR_variant
# 35079950 : 5_prime_UTR_variant
# 35080651 : splice_region_variant&synonymous_variant,synonymous_variant
# 35082257 : synonymous_variant,3_prime_UTR_variant
# 35082460 : missense_variant,3_prime_UTR_variant
# 35082465 : missense_variant,3_prime_UTR_variant
# 35082674 : synonymous_variant,3_prime_UTR_variant
#
# BaRT2v18chr3HG123130:
# 35119035 : 5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
# 35120211 : 3_prime_UTR_variant
# 35120238 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG123140:
# 35132007 : 3_prime_UTR_variant
# 35132279 : 3_prime_UTR_variant
# 35132380 : 3_prime_UTR_variant
# 35132434 : 3_prime_UTR_variant
# 35133408 : synonymous_variant
# 35133421 : missense_variant
# 35133481 : frameshift_variant
# 35133509 : synonymous_variant
#
# BaRT2v18chr3HG123160:
# 35151670 : missense_variant
# 35152022 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG123150:
# 35151670 : synonymous_variant
# 35152022 : synonymous_variant
#
# BaRT2v18chr3HG123150-BaRT2v18chr3HG123170:
#
# BaRT2v18chr3HG123180:
# 35319569 : 3_prime_UTR_variant
# 35319772 : stop_lost
#
# BaRT2v18chr3HG123190:
# 35319772 : splice_region_variant&intron_variant,5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
#
# BaRT2v18chr3HG123200:
#
# BaRT2v18chr3HG123210:
#
# BaRT2v18chr3HG123180-BaRT2v18chr3HG123200:
#
# BaRT2v18chr3HG123220:
# 35389119 : missense_variant
# 35389331 : missense_variant
#
# BaRT2v18chr3HG123210-BaRT2v18chr3HG123220:
#
# BaRT2v18chr3HG123250:
# 35489658 : missense_variant
# 35489686 : missense_variant
# 35489826 : missense_variant
# 35490018 : 5_prime_UTR_variant
# 35490067 : 5_prime_UTR_variant
#
# BaRT2v18chr3HG123260:
# 35766007 : missense_variant
# 35766138 : synonymous_variant
# 35766222 : synonymous_variant
# 35766597 : synonymous_variant
# 35766622 : synonymous_variant
# 35766680 : missense_variant
# 35766696 : synonymous_variant
# 35766755 : missense_variant
#
# BaRT2v18chr3HG123270:
# 36013467 : synonymous_variant
# 36013908 : 5_prime_UTR_variant
# 36014042 : 5_prime_UTR_variant
# 36014079 : 5_prime_UTR_variant
#
# BaRT2v18chr3HG123280:
# 36013467 : 5_prime_UTR_variant
# 36013908 : synonymous_variant
# 36014042 : missense_variant
# 36019106 : synonymous_variant
# 36019155 : missense_variant
# 36019356 : synonymous_variant
# 36019370 : missense_variant
# 36019463 : disruptive_inframe_insertion
# 36019506 : synonymous_variant
# 36019846 : missense_variant
# 36020006 : missense_variant
# 36020072 : missense_variant
# 36020089 : missense_variant
# 36020097 : synonymous_variant
# 36020510 : 3_prime_UTR_variant
# 36020537 : 3_prime_UTR_variant
# 36020550 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG123360:
#
# BaRT2v18chr3HG123350:
# 36112349 : synonymous_variant
# 36112858 : 3_prime_UTR_variant
# 36112925 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG123370:
#
# BaRT2v18chr3HG123380:
# 36160756 : 3_prime_UTR_variant
# 36161744 : synonymous_variant,3_prime_UTR_variant
# 36161849 : synonymous_variant,3_prime_UTR_variant
# 36161852 : synonymous_variant,3_prime_UTR_variant
# 36162341 : missense_variant,3_prime_UTR_variant
# 36163244 : 3_prime_UTR_variant
# 36164336 : synonymous_variant,3_prime_UTR_variant
# 36164764 : 3_prime_UTR_variant
# 36165670 : missense_variant
# 36166492 : 5_prime_UTR_variant
# 36166773 : 5_prime_UTR_variant
# 36166948 : 5_prime_UTR_variant
# 36167173 : 5_prime_UTR_variant
# 36167252 : 5_prime_UTR_variant
# 36167404 : 5_prime_UTR_variant
#
# BaRT2v18chr3HG123410:
# 36310248 : missense_variant
# 36310302 : synonymous_variant
# 36310353 : synonymous_variant
# 36310405 : synonymous_variant
# 36310551 : synonymous_variant
# 36311012 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG123400:
# 36310248 : missense_variant
# 36310302 : missense_variant
# 36310353 : missense_variant
# 36310405 : synonymous_variant
# 36310551 : missense_variant
# 36311012 : missense_variant
#
# BaRT2v18chr3HG123390-BaRT2v18chr3HG123400:
#
# BaRT2v18chr3HG123410-BaRT2v18chr3HG123420:
#
# BaRT2v18chr3HG123420:
# 36340259 : 3_prime_UTR_variant
# 36340373 : 3_prime_UTR_variant
# 36341289 : synonymous_variant,3_prime_UTR_variant
# 36341534 : synonymous_variant,3_prime_UTR_variant
# 36341645 : synonymous_variant,3_prime_UTR_variant
# 36343629 : synonymous_variant
# 36343638 : synonymous_variant
# 36343792 : 5_prime_UTR_premature_start_codon_gain_variant,5_prime_UTR_variant
#
# BaRT2v18chr3HG123430:
# 36389236 : 3_prime_UTR_variant
# 36389359 : 3_prime_UTR_variant
# 36389403 : 3_prime_UTR_variant
# 36389475 : 3_prime_UTR_variant
# 36389539 : synonymous_variant,3_prime_UTR_variant
#
# BaRT2v18chr3HG123420-BaRT2v18chr3HG123430:
#
# BaRT2v18chr3HG123440:
# 36397547 : 3_prime_UTR_variant
# 36397563 : 3_prime_UTR_variant
# 36397586 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG123440-BaRT2v18chr3HG123450:
#
# BaRT2v18chr3HG123480:
# 36577111 : 3_prime_UTR_variant
# 36577209 : splice_region_variant,3_prime_UTR_variant
# 36577257 : 3_prime_UTR_variant
# 36577301 : 3_prime_UTR_variant
# 36577464 : 3_prime_UTR_variant
# 36578235 : missense_variant,3_prime_UTR_variant
# 36578975 : 3_prime_UTR_variant
# 36580924 : 3_prime_UTR_variant
# 36581027 : 3_prime_UTR_variant
# 36581207 : 3_prime_UTR_variant
# 36581689 : 3_prime_UTR_variant
# 36581814 : 3_prime_UTR_variant
# 36581923 : 3_prime_UTR_variant
# 36582042 : missense_variant
# 36582714 : splice_donor_variant&intron_variant
# 36582792 : 5_prime_UTR_variant
#
# BaRT2v18chr3HG123470:
#
# BaRT2v18chr3HG123490:
# 36857104 : 3_prime_UTR_variant
# 36857114 : 3_prime_UTR_variant
# 36859120 : 3_prime_UTR_variant
#
# BaRT2v18chr3HG123490-BaRT2v18chr3HG123500:
#
# BaRT2v18chr3HG123500:
# 36890032 : synonymous_variant
#
#
# Length of Instances is 63
# KeyError for gene BaRT2v18chr3HG122940-BaRT2v18chr3HG122950
# KeyError for gene BaRT2v18chr3HG122950-BaRT2v18chr3HG122960
# KeyError for gene BaRT2v18chr3HG122980-BaRT2v18chr3HG122990
# KeyError for gene BaRT2v18chr3HG122990-BaRT2v18chr3HG123000
# KeyError for gene BaRT2v18chr3HG123000-BaRT2v18chr3HG123010
# KeyError for gene BaRT2v18chr3HG123010-BaRT2v18chr3HG123030
# KeyError for gene BaRT2v18chr3HG123030-BaRT2v18chr3HG123040
# KeyError for gene BaRT2v18chr3HG123040-BaRT2v18chr3HG123060
# KeyError for gene BaRT2v18chr3HG123110-BaRT2v18chr3HG123120
# KeyError for gene BaRT2v18chr3HG123150-BaRT2v18chr3HG123170
# KeyError for gene BaRT2v18chr3HG123180-BaRT2v18chr3HG123200
# KeyError for gene BaRT2v18chr3HG123210-BaRT2v18chr3HG123220
# KeyError for gene BaRT2v18chr3HG123390-BaRT2v18chr3HG123400
# KeyError for gene BaRT2v18chr3HG123410-BaRT2v18chr3HG123420
# KeyError for gene BaRT2v18chr3HG123420-BaRT2v18chr3HG123430
# KeyError for gene BaRT2v18chr3HG123440-BaRT2v18chr3HG123450
# KeyError for gene BaRT2v18chr3HG123490-BaRT2v18chr3HG123500

# %%
gene_annotation = pd.read_csv(expression_info,engine="c",index_col=0)
gene_annotation.head()
# Out:
#                       HID19.1-Barke.1  HID56.1-Barke.1  HEB_124_17.2-Barke.2  \
# BaRT2v18chr1HG000020         0.002923         0.178220              0.953696
# BaRT2v18chr1HG000040         0.008994         0.006047              0.984281
# BaRT2v18chr1HG000050         0.063700         0.937603              1.000000
# BaRT2v18chr1HG000060         0.015122         0.169527              1.000000
# BaRT2v18chr1HG000070         0.000618         0.005162              0.985872
#
#                       HEB_124_52.2-Barke.2  HEB_124_52.2-HEB_124_17.2
# BaRT2v18chr1HG000020              0.176870                   0.936994
# BaRT2v18chr1HG000040              0.879735                   0.940247
# BaRT2v18chr1HG000050              0.953811                   0.976945
# BaRT2v18chr1HG000060              0.838232                   0.970221
# BaRT2v18chr1HG000070              0.528943                   0.920581
